# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Global YouTube Statistics.csv', encoding="ISO-8859-1")
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# 1    Film & Animation               youtubemovies        1   United States
# 2       Entertainment                     MrBeast      741   United States
# 3           Education  Cocomelon - Nursery Rhymes      966   United States
# 4               Shows                   SET India   116536           India
# ..                ...                         ...      ...             ...
# 990            Sports               Natan por Aï¿     1200          Brazil
# 991    People & Blogs    Free Fire India Official     1500           India
# 992               NaN                 HybridPanda     2452  United Kingdom
# 993            Gaming                 RobTopGames       39          Sweden
# 994            Comedy                Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0             IN          Music  ...                     2000000.0
# 1             US          Games  ...                           NaN
# 2             US  Entertainment  ...                     8000000.0
# 3             US      Education  ...                     1000000.0
# 4             IN  Entertainment  ...                     1000000.0
# ..           ...            ...  ...                           ...
# 990           BR  Entertainment  ...                      700000.0
# 991           IN          Games  ...                      300000.0
# 992           GB          Games  ...                        1000.0
# 993           SE          Games  ...                      100000.0
# 994           IN         Comedy  ...                      100000.0
#
#      created_year  created_month  created_date  \
# 0          2006.0            Mar          13.0
# 1          2006.0            Mar           5.0
# 2          2012.0            Feb          20.0
# 3          2006.0            Sep           1.0
# 4          2006.0            Sep          20.0
# ..            ...            ...           ...
# 990        2017.0            Feb          12.0
# 991        2018.0            Sep          14.0
# 992        2006.0            Sep          11.0
# 993        2012.0            May           9.0
# 994        2017.0            Aug           1.0
#
#      Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                       28.1  1.366418e+09               5.36
# 1                                       88.2  3.282395e+08              14.70
# 2                                       88.2  3.282395e+08              14.70
# 3                                       88.2  3.282395e+08              14.70
# 4                                       28.1  1.366418e+09               5.36
# ..                                       ...           ...                ...
# 990                                     51.3  2.125594e+08              12.08
# 991                                     28.1  1.366418e+09               5.36
# 992                                     60.0  6.683440e+07               3.85
# 993                                     67.0  1.028545e+07               6.48
# 994                                     28.1  1.366418e+09               5.36
#
#      Urban_population   Latitude  Longitude
# 0         471031528.0  20.593684  78.962880
# 1         270663028.0  37.090240 -95.712891
# 2         270663028.0  37.090240 -95.712891
# 3         270663028.0  37.090240 -95.712891
# 4         471031528.0  20.593684  78.962880
# ..                ...        ...        ...
# 990       183241641.0 -14.235004 -51.925280
# 991       471031528.0  20.593684  78.962880
# 992        55908316.0  55.378051  -3.435973
# 993         9021165.0  60.128161  18.643501
# 994       471031528.0  20.593684  78.962880
#
# [995 rows x 28 columns]

# %% [markdown]
# Data preprocessing is a critical step in analyzing our dataset as it helps ensure subsequent analyses' accuracy and reliability. We outline the various preprocessing methods employed to enhance the quality and usability of the dataset. These methods include removing unnecessary features, handling missing values, addressing outliers, encoding categorical variables, and performing feature engineering.
# After thorough consideration and discussion, our group first conducted data cleaning to identify and remove irrelevant features. This step helps to reduce noise and increase the efficiency of subsequent analysis. Irrelevant variables include title, abbreviation, rank, created_month, etc. To simplify the analysis, we calculated the average annual revenue as an indicator and replaced various earnings-related variables with it. In addition, we have removed the rows where the earnings are 0.
# Outliers can skew statistical analyses and lead to misleading results. For example, the cluster analytics is sensitive to outliers. To ensure a robust and accurate analysis, we identified and addressed outliers. We have plotted a scatter plot comparing earnings and subscribers. To avoid the influence of outliers on the overall data, we have removed values with “subscribers” greater than 10^6. Also, we have only kept values of “average yearly earnings” between around 9*10^3 and 9*10^8. Figure 4.1 shows the relationship between average yearly earnings and subscribers, before and after outlier processing.
# In addition, we found some channels that have extremely high views but only very low earnings, such as some singers. After checking the information, we found that their main income is not from the YouTube platform, but from other companies or individual channels. Therefore, we calculated the ratio of views to earnings, thus removing some channels with extreme cases (Figure 4.2).
# Categorical variables, such as 'category' and 'country', were encoded numerically using either one-hot or label encoding methods, to enable their inclusion in statistical analyses.

# %%
df['average_yearly_earnings'] = (df['highest_yearly_earnings'] + df['lowest_yearly_earnings'])/2

# 查看average_yearly_earnings和subscribers的散点图
plt.scatter(df['average_yearly_earnings'], df['subscribers'])
plt.xlabel('Average Yearly Earnings')
plt.ylabel('Subscribers')
plt.title('Scatter Plot of Average Yearly Earnings vs Subscribers')
plt.show()

# %%
# 删除离群
df1 = df[df['average_yearly_earnings'] < 5 * 10**7]
df1 = df1[df1['subscribers'] < 1.5 * 10**8]
df1 = df1[df1['average_yearly_earnings'] > 1000]
df1 = df1[df1['uploads'] > 0]
df1.dropna(subset=['Country'], inplace=True)
df1.dropna(subset=['subscribers_for_last_30_days'], inplace=True)
df1.dropna(subset=['average_yearly_earnings'], inplace=True)

plt.scatter(df1['average_yearly_earnings'], df1['subscribers'])
plt.xlabel('Average Yearly Earnings')
plt.ylabel('Subscribers')
plt.title('Scatter Plot of Average Yearly Earnings vs Subscribers')
plt.show()

# %%
df1['average_yearly_earnings']
# Out:
# 8       1223400.0
# 9      14800000.0
# 10     20500000.0
# 11     18200000.0
# 13     12700000.0
#           ...
# 990    14100000.0
# 991     1647100.0
# 992        1700.5
# 993       98700.0
# 994      636000.0
# Name: average_yearly_earnings, Length: 550, dtype: float64

# %%
df1["views_earn_rate"] = df1['video views']/df1['average_yearly_earnings']
df1["views_earn_rate"]

plt.scatter(df1['average_yearly_earnings'], df1['views_earn_rate'])
plt.xlabel('average_yearly_earnings')
plt.ylabel('views_earn_rate')
plt.title('Scatter Plot of Earnings vs Views Earn Rate')
plt.show()

# %%
df1[df1["views_earn_rate"]>3*1e4]
# Out:
#      rank         Youtuber  subscribers   video views        category  \
# 8       9      Like Nastya    106000000  9.047906e+10  People & Blogs
# 85     86             shfa     38400000  2.152812e+10  People & Blogs
# 131   132   Eros Now Music     32700000  1.785380e+10   Entertainment
# 407   408     Crafty Panda     19800000  5.759442e+09  People & Blogs
# 484   485     David Dobrik     17900000  7.176572e+09  People & Blogs
# 619   620        MY FAMILY     15700000  6.153496e+09             NaN
# 716   717  Canal Nostalgia     14700000  1.506796e+09   Entertainment
# 759   760      Coke Studio     14400000  4.035739e+09           Music
# 768   769     Super Polina     14300000  4.776507e+09  People & Blogs
# 848   849           Wengie     13500000  1.900273e+09   Howto & Style
# 873   874         AzzyLand     13300000  6.412314e+09          Gaming
# 936   937           Future     12700000  9.927699e+09           Music
# 992   993            Panda     12300000  2.214684e+09             NaN
#
#                   Title  uploads         Country Abbreviation   channel_type  \
# 8      Like Nastya Vlog      493          Russia           RU         People
# 85    ýýýýýýýýýý ýýýýýý      982    Saudi Arabia           SA          Games
# 131              Mzaalo     1521           India           IN  Entertainment
# 407        Crafty Panda      760   United States           US  Entertainment
# 484        David Dobrik      536   United States           US         People
# 619           My Family      150       Singapore           SG         People
# 716  Canal Nostalgia TV      554           Spain           ES  Entertainment
# 759        Rohail Hyatt      450   United States           US          Music
# 768        Super Polina      576   United States           US  Entertainment
# 848              Wengie      462   United States           US          Howto
# 873            AzzyLand     1749          Canada           CA  Entertainment
# 936        Future AMV's      119   United States           US           Film
# 992         HybridPanda     2452  United Kingdom           GB          Games
#
#      ...  created_month  created_date  \
# 8    ...            Jan          14.0
# 85   ...            May          24.0
# 131  ...            Mar          14.0
# 407  ...            Dec           3.0
# 484  ...            Dec          19.0
# 619  ...            Dec           3.0
# 716  ...            Feb          19.0
# 759  ...            Jun           4.0
# 768  ...            Jul           8.0
# 848  ...            Sep           9.0
# 873  ...            May           8.0
# 936  ...            Nov           7.0
# 992  ...            Sep          11.0
#
#      Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 8                                       81.9  1.443735e+08               4.59
# 85                                      68.0  3.426853e+07               5.93
# 131                                     28.1  1.366418e+09               5.36
# 407                                     88.2  3.282395e+08              14.70
# 484                                     88.2  3.282395e+08              14.70
# 619                                     84.8  5.703569e+06               4.11
# 716                                     88.9  4.707678e+07              13.96
# 759                                     88.2  3.282395e+08              14.70
# 768                                     88.2  3.282395e+08              14.70
# 848                                     88.2  3.282395e+08              14.70
# 873                                     68.9  3.699198e+07               5.56
# 936                                     88.2  3.282395e+08              14.70
# 992                                     60.0  6.683440e+07               3.85
#
#      Urban_population   Latitude   Longitude  average_yearly_earnings  \
# 8         107683889.0  61.524010  105.318756                1223400.0
# 85         28807838.0  23.885942   45.079162                  40550.0
# 131       471031528.0  20.593684   78.962880                 516700.0
# 407       270663028.0  37.090240  -95.712891                 156500.0
# 484       270663028.0  37.090240  -95.712891                 220600.0
# 619         5703569.0   1.352083  103.819836                  23950.0
# 716        37927409.0  40.463667   -3.749220                   5789.5
# 759       270663028.0  37.090240  -95.712891                  90700.0
# 768       270663028.0  37.090240  -95.712891                  10550.0
# 848       270663028.0  37.090240  -95.712891                  34050.0
# 873        30628482.0  56.130366 -106.346771                 137400.0
# 936       270663028.0  37.090240  -95.712891                  12050.0
# 992        55908316.0  55.378051   -3.435973                   1700.5
#
#      views_earn_rate
# 8       7.395705e+04
# 85      5.309030e+05
# 131     3.455351e+04
# 407     3.680155e+04
# 484     3.253206e+04
# 619     2.569309e+05
# 716     2.602636e+05
# 759     4.449547e+04
# 768     4.527495e+05
# 848     5.580831e+04
# 873     4.666895e+04
# 936     8.238755e+05
# 992     1.302372e+06
#
# [13 rows x 30 columns]

# %%
df1 = df1[df1["views_earn_rate"]<3*1e4]
plt.scatter(df1['average_yearly_earnings'], df1['views_earn_rate'])
plt.xlabel('Earnings')
plt.ylabel('views_earn_rate')
plt.title('Scatter Plot of Earnings vs Views Earn Rate')
plt.show()

# %%
df1.describe()
# Out:
#              rank   subscribers   video views        uploads  \
# count  537.000000  5.370000e+02  5.370000e+02     537.000000
# mean   469.530726  2.329646e+07  1.209776e+10   14784.515829
# std    288.969559  1.338707e+07  1.152772e+10   44530.313378
# min     10.000000  1.230000e+07  2.056338e+07      15.000000
# 25%    215.000000  1.470000e+07  4.924054e+09     498.000000
# 50%    454.000000  1.860000e+07  9.052368e+09    1299.000000
# 75%    719.000000  2.620000e+07  1.527867e+10    4175.000000
# max    995.000000  9.890000e+07  1.010000e+11  301308.000000
#
#        video_views_rank  country_rank  channel_type_rank  \
# count        537.000000    537.000000         537.000000
# mean        2096.256983     57.459963          62.381750
# std        15156.614427     52.840816          50.546948
# min            4.000000      1.000000           1.000000
# 25%          213.000000     10.000000          18.000000
# 50%          530.000000     38.000000          45.000000
# 75%         1399.000000    101.000000         104.000000
# max       342460.000000    176.000000         172.000000
#
#        video_views_for_the_last_30_days  lowest_monthly_earnings  \
# count                      5.370000e+02               537.000000
# mean                       2.134485e+08             53364.068901
# std                        2.695966e+08             67403.545523
# min                        1.370000e+06               342.000000
# 25%                        5.621800e+07             14100.000000
# 50%                        1.229260e+08             30700.000000
# 75%                        2.509950e+08             62700.000000
# max                        1.707000e+09            426800.000000
#
#        highest_monthly_earnings  ...  created_year  created_date  \
# count              5.370000e+02  ...    537.000000    537.000000
# mean               8.531924e+05  ...   2012.778399     15.234637
# std                1.077770e+06  ...      4.541810      8.869749
# min                5.500000e+03  ...   1970.000000      1.000000
# 25%                2.249000e+05  ...   2010.000000      8.000000
# 50%                4.917000e+05  ...   2013.000000     15.000000
# 75%                1.000000e+06  ...   2016.000000     23.000000
# max                6.800000e+06  ...   2022.000000     31.000000
#
#        Gross tertiary education enrollment (%)    Population  \
# count                               537.000000  5.370000e+02
# mean                                 60.089013  5.039674e+08
# std                                  26.405773  5.190667e+08
# min                                   9.000000  2.870250e+05
# 25%                                  28.100000  1.081166e+08
# 50%                                  60.000000  3.282395e+08
# 75%                                  88.200000  1.366418e+09
# max                                 113.100000  1.397715e+09
#
#        Unemployment rate  Urban_population    Latitude   Longitude  \
# count         537.000000      5.370000e+02  537.000000  537.000000
# mean            8.888324      2.434258e+08   25.955345   -5.453916
# std             4.842469      1.636545e+08   19.878869   84.711996
# min             0.750000      8.943100e+04  -38.416097 -106.346771
# 25%             5.360000      6.432484e+07   20.593684  -95.712891
# 50%             5.560000      2.706630e+08   26.820553   -3.435973
# 75%            14.700000      4.710315e+08   37.090240   78.962880
# max            14.720000      8.429340e+08   61.524010  138.252924
#
#        average_yearly_earnings  views_earn_rate
# count             5.370000e+02       537.000000
# mean              5.442826e+06      3778.064314
# std               6.874407e+06      3481.099721
# min               3.490000e+04        39.292827
# 25%               1.434350e+06      1632.275286
# 50%               3.134400e+06      2906.932824
# 75%               6.376500e+06      4711.802860
# max               4.350000e+07     29860.976082
#
# [8 rows x 23 columns]

# %%
#初步筛掉的特征（用于proposal），此段可删
feature_drop = ["video_views_rank", "Abbreviation","lowest_monthly_earnings", 
                "highest_monthly_earnings", "lowest_yearly_earnings", "highest_yearly_earnings","Title",
                "channel_type", "created_date", "created_month"
                ]
df1.drop(feature_drop, axis=1, inplace=True)
df1
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 9      10             Vlad and Niki     98900000  7.718017e+10
# 10     11         Zee Music Company     96700000  5.785629e+10
# 11     12                       WWE     96000000  7.742847e+10
# 13     14                 BLACKPINK     89800000  3.214460e+10
# 15     16                  Sony SAB     83000000  1.010000e+11
# ..    ...                       ...          ...           ...
# 989   990                 Migos ATL     12400000  6.993406e+09
# 990   991             Natan por Aï¿     12300000  9.029610e+09
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 993   994               RobTopGames     12300000  3.741235e+08
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#            category  uploads        Country  country_rank  channel_type_rank  \
# 9     Entertainment      574  United States           5.0                6.0
# 10            Music     8548          India           3.0                2.0
# 11           Sports    70127  United States           6.0                1.0
# 13   People & Blogs      543    South Korea           1.0                3.0
# 15            Shows    71270          India           5.0                7.0
# ..              ...      ...            ...           ...                ...
# 989           Music       99  United States         175.0              171.0
# 990          Sports     1200         Brazil          55.0              172.0
# 991  People & Blogs     1500          India         125.0               69.0
# 993          Gaming       39         Sweden           4.0               69.0
# 994          Comedy       62          India         125.0               44.0
#
#      video_views_for_the_last_30_days  subscribers_for_last_30_days  \
# 9                        5.805740e+08                      600000.0
# 10                       8.036130e+08                     1100000.0
# 11                       7.146140e+08                      600000.0
# 13                       4.989300e+08                      700000.0
# 15                       1.657000e+09                     1100000.0
# ..                                ...                           ...
# 989                      4.941200e+07                      100000.0
# 990                      5.525130e+08                      700000.0
# 991                      6.473500e+07                      300000.0
# 993                      3.871000e+06                      100000.0
# 994                      2.400000e+07                      100000.0
#
#      created_year  Gross tertiary education enrollment (%)    Population  \
# 9          2018.0                                     88.2  3.282395e+08
# 10         2014.0                                     28.1  1.366418e+09
# 11         2007.0                                     88.2  3.282395e+08
# 13         2016.0                                     94.3  5.170910e+07
# 15         2007.0                                     28.1  1.366418e+09
# ..            ...                                      ...           ...
# 989        2012.0                                     88.2  3.282395e+08
# 990        2017.0                                     51.3  2.125594e+08
# 991        2018.0                                     28.1  1.366418e+09
# 993        2012.0                                     67.0  1.028545e+07
# 994        2017.0                                     28.1  1.366418e+09
#
#      Unemployment rate  Urban_population   Latitude   Longitude  \
# 9                14.70       270663028.0  37.090240  -95.712891
# 10                5.36       471031528.0  20.593684   78.962880
# 11               14.70       270663028.0  37.090240  -95.712891
# 13                4.15        42106719.0  35.907757  127.766922
# 15                5.36       471031528.0  20.593684   78.962880
# ..                 ...               ...        ...         ...
# 989              14.70       270663028.0  37.090240  -95.712891
# 990              12.08       183241641.0 -14.235004  -51.925280
# 991               5.36       471031528.0  20.593684   78.962880
# 993               6.48         9021165.0  60.128161   18.643501
# 994               5.36       471031528.0  20.593684   78.962880
#
#      average_yearly_earnings  views_earn_rate
# 9                 14800000.0      5214.876344
# 10                20500000.0      2822.258019
# 11                18200000.0      4254.311740
# 13                12700000.0      2531.070674
# 15                42300000.0      2387.706856
# ..                       ...              ...
# 989                1274100.0      5488.899034
# 990               14100000.0       640.397855
# 991                1647100.0      1016.580624
# 993                  98700.0      3790.511479
# 994                 636000.0      3348.700808
#
# [537 rows x 20 columns]

# %%
# 决定应用的特征
feature_1 = ["subscribers", "video views", "category", "Unemployment rate", "Population", "video_views_for_the_last_30_days", "average_yearly_earnings"]
earnings_distribution = df1['average_yearly_earnings'].value_counts()

# %%
# 创建"existed_time"列
df1['existed_time'] = 2023 - df1['created_year']

# 创建"upload_frequency"列
df1['upload_frequency'] = (df1['uploads'] / df1['existed_time'])
# df1['average_yearly_earnings'] = np.log(df1['average_yearly_earnings'])

# %%
#相关性热力图

import matplotlib.pyplot as plt
import seaborn as sns

# Selecting numerical columns
numerical_columns = df1.select_dtypes(include=['int64', 'float64'])

# Calculate the correlation matrix
correlation_matrix = numerical_columns.corr()

# Set up the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True, square=True)

# Title
plt.title('Correlation Heatmap of YouTube Data')
plt.savefig('相关性热力图.png', format='png')

# %%
# 计算所有组合类型的数量
counts = df.groupby(['Country', 'category']).size().reset_index(name='Count')

print(counts)
# Out:
#            Country        category  Count
# 0      Afghanistan           Music      1
# 1          Andorra   Howto & Style      1
# 2        Argentina          Comedy      3
# 3        Argentina       Education      1
# 4        Argentina   Entertainment      3
# ..             ...             ...    ...
# 174  United States          Sports      5
# 175      Venezuela  People & Blogs      1
# 176        Vietnam          Comedy      1
# 177        Vietnam   Entertainment      1
# 178        Vietnam           Music      1
#
# [179 rows x 3 columns]

# %%
# 使用Pandas的get_dummies函数进行One-Hot Encoding
df1 = pd.get_dummies(df1, columns=['category'])
df1 = pd.get_dummies(df1, columns=['Country'])
df1
# Out:
#      rank                  Youtuber  subscribers   video views  uploads  \
# 9      10             Vlad and Niki     98900000  7.718017e+10      574
# 10     11         Zee Music Company     96700000  5.785629e+10     8548
# 11     12                       WWE     96000000  7.742847e+10    70127
# 13     14                 BLACKPINK     89800000  3.214460e+10      543
# 15     16                  Sony SAB     83000000  1.010000e+11    71270
# ..    ...                       ...          ...           ...      ...
# 989   990                 Migos ATL     12400000  6.993406e+09       99
# 990   991             Natan por Aï¿     12300000  9.029610e+09     1200
# 991   992  Free Fire India Official     12300000  1.674410e+09     1500
# 993   994               RobTopGames     12300000  3.741235e+08       39
# 994   995              Make Joke Of     12300000  2.129774e+09       62
#
#      country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# 9             5.0                6.0                      5.805740e+08
# 10            3.0                2.0                      8.036130e+08
# 11            6.0                1.0                      7.146140e+08
# 13            1.0                3.0                      4.989300e+08
# 15            5.0                7.0                      1.657000e+09
# ..            ...                ...                               ...
# 989         175.0              171.0                      4.941200e+07
# 990          55.0              172.0                      5.525130e+08
# 991         125.0               69.0                      6.473500e+07
# 993           4.0               69.0                      3.871000e+06
# 994         125.0               44.0                      2.400000e+07
#
#      subscribers_for_last_30_days  created_year  ...  Country_Spain  \
# 9                        600000.0        2018.0  ...              0
# 10                      1100000.0        2014.0  ...              0
# 11                       600000.0        2007.0  ...              0
# 13                       700000.0        2016.0  ...              0
# 15                      1100000.0        2007.0  ...              0
# ..                            ...           ...  ...            ...
# 989                      100000.0        2012.0  ...              0
# 990                      700000.0        2017.0  ...              0
# 991                      300000.0        2018.0  ...              0
# 993                      100000.0        2012.0  ...              0
# 994                      100000.0        2017.0  ...              0
#
#      Country_Sweden  Country_Switzerland  Country_Thailand  Country_Turkey  \
# 9                 0                    0                 0               0
# 10                0                    0                 0               0
# 11                0                    0                 0               0
# 13                0                    0                 0               0
# 15                0                    0                 0               0
# ..              ...                  ...               ...             ...
# 989               0                    0                 0               0
# 990               0                    0                 0               0
# 991               0                    0                 0               0
# 993               1                    0                 0               0
# 994               0                    0                 0               0
#
#      Country_Ukraine  Country_United Arab Emirates  Country_United Kingdom  \
# 9                  0                             0                       0
# 10                 0                             0                       0
# 11                 0                             0                       0
# 13                 0                             0                       0
# 15                 0                             0                       0
# ..               ...                           ...                     ...
# 989                0                             0                       0
# 990                0                             0                       0
# 991                0                             0                       0
# 993                0                             0                       0
# 994                0                             0                       0
#
#      Country_United States  Country_Vietnam
# 9                        1                0
# 10                       0                0
# 11                       1                0
# 13                       0                0
# 15                       0                0
# ..                     ...              ...
# 989                      1                0
# 990                      0                0
# 991                      0                0
# 993                      0                0
# 994                      0                0
#
# [537 rows x 76 columns]

# %%
df1.to_excel('preprocess.xlsx', index=False, encoding="UTF-8")
counts.to_excel('counts.xlsx', index=False, encoding="UTF-8")
# Out:
# /Users/duansuyang/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)
